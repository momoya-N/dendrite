# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
DLA=np.loadtxt("Shape.dat")

plt.imshow(DLA, cmap="gray")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Phi=np.loadtxt("Phi.dat")

fig,ax = plt.subplots(figsize=(9, 9))
plt.tight_layout()
Phi_value=Phi[:,2].reshape([512,512])

plt.imshow(Phi_value)
#plt.imshow(Phi_value,cmap=plt.cm.jet)
#plt.clim(4.999,5)

# %%
El=np.loadtxt("El.dat")
fig = plt.figure(figsize=(9, 9))

x=El[:,0]
y=El[:,1]
Ex=El[:,3]
Ey=El[:,4]
El_value=El[:,2]

El_value=El[:,2].reshape([510,510])#N-2の大きさ

# scaling=100
#plt.quiver(x, y, Ex, Ey)

plt.imshow(El_value)
#plt.imshow(El_value,cmap=plt.cm.jet)

# %%
errtest=np.loadtxt("errtest.dat")

plt.imshow(errtest)
plt.colorbar(aspect=40, pad=0.08, shrink=0.6,orientation='horizontal', extend='both')           
           
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
